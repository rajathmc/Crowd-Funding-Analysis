# %% [markdown]
# # Kiva Crowd-Funding Analysis
# This notebook loads the Kiva dataset for analysis.

# %%
from pathlib import Path
DATA_DIR = Path('input')
print('Data directory:', DATA_DIR.resolve())

# %%
import pandas as pd
loans_path = DATA_DIR / 'data-science-for-good-kiva-crowdfunding' / 'kiva_loans.csv'
try:
    loans = pd.read_csv(loans_path)
    print('Loaded', len(loans), 'loans')
except FileNotFoundError:
    print('Data file not found:', loans_path)
